# %%
import pandas as pd
# importing pandas library, this is not available by default.
# pd is it alias

# %% [markdown]
# ### Reading different files using pandas.
#
# We type pd.read_filetype
#
# For reference examples are shown below.

# %%
# reading a csv file
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# ### First row is considered as column name in given dataset.
#
# In a case where data first row don't have column name, all enteries present in first row will be considered as column name.
#
# Pandas try to give you structured data in a tubular form.
#
# Pandas do the default row indexing if explicit row indexing is not mentioned by the user and the implicit value of row indexing starts from 0 as can be seen from above table.

# %%
df = pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv')

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.head()
# head() is a inbuilt function for pandas which displayes the first 5 records by default
# You can view only first 2 records by df.head(2)
# So in order to view starting 'n' records you can use head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
# 3  2020                     Level 1                99999       All industries
# 4  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.head(2)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  733,258  ANZSIC06 divisions A-S (excluding classes K633...
# 1  660,630  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df.head(15)
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2020                     Level 1                99999
# 1   2020                     Level 1                99999
# 2   2020                     Level 1                99999
# 3   2020                     Level 1                99999
# 4   2020                     Level 1                99999
# 5   2020                     Level 1                99999
# 6   2020                     Level 1                99999
# 7   2020                     Level 1                99999
# 8   2020                     Level 1                99999
# 9   2020                     Level 1                99999
# 10  2020                     Level 1                99999
# 11  2020                     Level 1                99999
# 12  2020                     Level 1                99999
# 13  2020                     Level 1                99999
# 14  2020                     Level 1                99999
#
# ...

# %%
df.tail()
# tail() is a inbuilt function for pandas which displayes the last 5 records by default
# You can view only last 2 records by df.tail(2)
# So in order to view starting 'n' records you can use tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37075  Food product manufacturing  Percentage           H37
# 37076  Food product manufacturing  Percentage           H38
# 37077  Food product manufacturing  Percentage           H39
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 37075                          Quick ratio  Financial ratios    52
# 37076  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df.tail(2)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 37078  Food product manufacturing  Percentage           H40
# 37079  Food product manufacturing  Percentage           H41
#
#                 Variable_name Variable_category Value  \
# 37078  Return on total assets  Financial ratios     5
# 37079   Liabilities structure  Financial ratios    46
#
#                                   Industry_code_ANZSIC06
# 37078  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37079  ANZSIC06 groups C111, C112, C113, C114, C115, ...

# %%
df.tail(12)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37068  2013                     Level 3                 ZZ11
# 37069  2013                     Level 3                 ZZ11
# 37070  2013                     Level 3                 ZZ11
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 37068  Food product manufacturing  Dollars (millions)           H30
# ...

# %% [markdown]
# ### In order to store data in a csv format we can use to_csv command as shown below.

# %%
df1 = df.tail(12)

# %%
df1.to_csv('dftail.csv')

# %%
pd.read_csv('dftail.csv')
# in below data we can see that unnamed column is added
# this is because every first row element is converted to column name
# Out:
#     Unnamed: 0  Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0        37068  2013                     Level 3                 ZZ11
# 1        37069  2013                     Level 3                 ZZ11
# 2        37070  2013                     Level 3                 ZZ11
# 3        37071  2013                     Level 3                 ZZ11
# 4        37072  2013                     Level 3                 ZZ11
# 5        37073  2013                     Level 3                 ZZ11
# 6        37074  2013                     Level 3                 ZZ11
# 7        37075  2013                     Level 3                 ZZ11
# 8        37076  2013                     Level 3                 ZZ11
# 9        37077  2013                     Level 3                 ZZ11
# 10       37078  2013                     Level 3                 ZZ11
# 11       37079  2013                     Level 3                 ZZ11
#
# ...

# %% [markdown]
# ### Now first requirement is to read data without reading first column name of given csv file. Make header parameter = None

# %%
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df2=pd.read_csv('process.csv',delimiter= '    ')
# Out:
# <ipython-input-30-096af9df2d7e>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df2=pd.read_csv('process.csv',delimiter= '    ')

# %%
df2
# Out:
#     NPM(K)  PM(M)    WS(M)                        CPU(s)  \
# 0       27  17.29    36.16                          8.48
# 1        9   1.86     4.16                          0.00
# 2       53  51.80    49.80                          9.38
# 3       14  13.29    20.73      5.50   14332   0 audiodg
# 4        9   1.55     8.00                          0.05
# ..     ...    ...      ...                           ...
# 180     21  14.66    37.00                          4.78
# 181     11   1.49     4.15                          0.00
# 182     12   2.41     9.52     0.00   13748   3 winlogon
# 183     38  21.23     0.11                          0.41
# 184     13   3.66     7.82                          0.00
#
#                                     Id  SI ProcessName
# 0                        6524   3 ApplicationFrameHost
# 1                                      4656   0 armsvc
# 2                                       6120   3 atmgr
# 3                                                 None
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   NPM(K)                185 non-null    object
#  1   PM(M)                 185 non-null    float64
#  2     WS(M)               185 non-null    object
#  3    CPU(s)               183 non-null    object
#  4     Id  SI ProcessName  137 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 7.4+ KB

# %%
df2.describe()
# Out:
#             PM(M)
# count  185.000000
# mean    16.179297
# std     34.053164
# min      0.060000
# 25%      2.180000
# 50%      4.450000
# 75%     12.680000
# max    221.430000

# %%
df1
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 37068  2013                     Level 3                 ZZ11
# 37069  2013                     Level 3                 ZZ11
# 37070  2013                     Level 3                 ZZ11
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 37068  Food product manufacturing  Dollars (millions)           H30
# ...

# %% [markdown]
# ### Now first requirement is to read data without reading first column name of given csv file

# %%
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv')
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv',header=None)
# We can see that this time we recevie column indexes 
# Now first row is not considered as header as header = None is set by us.
# Out:
#           0                            1                     2  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1      2020                      Level 1                 99999
# 2      2020                      Level 1                 99999
# 3      2020                      Level 1                 99999
# 4      2020                      Level 1                 99999
# ...     ...                          ...                   ...
# 37076  2013                      Level 3                  ZZ11
# 37077  2013                      Level 3                  ZZ11
# 37078  2013                      Level 3                  ZZ11
# 37079  2013                      Level 3                  ZZ11
# 37080  2013                      Level 3                  ZZ11
#
#                                 3                   4              5  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %% [markdown]
# ### Requirement is given user defined colunm name.

# %%
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv',header=None,names=['a','b','c','d','e','f','g','i','j','k'])
# Out:
#           a                            b                     c  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1      2020                      Level 1                 99999
# 2      2020                      Level 1                 99999
# 3      2020                      Level 1                 99999
# 4      2020                      Level 1                 99999
# ...     ...                          ...                   ...
# 37076  2013                      Level 3                  ZZ11
# 37077  2013                      Level 3                  ZZ11
# 37078  2013                      Level 3                  ZZ11
# 37079  2013                      Level 3                  ZZ11
# 37080  2013                      Level 3                  ZZ11
#
#                                 d                   e              f  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv',header=None,names=['a','b','c'])
# In case you miss naming all column names you will recevie only thise colunm names that are present in 'names'
# Out:
#                                                                                                                                                                                        a  \
# Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC       Units              Variable_code Variable_name                                        Variable_category
# 2020 Level 1                     99999                All industries             Dollars (millions) H01           Total income                                     Financial performance
#                                                                                                     H04           Sales, government funding, grants and subsidies  Financial performance
#                                                                                                     H05           Interest, dividends and donations                Financial performance
# ...

# %% [markdown]
# ### Skipping rows in dataframe

# %%
df.head(3)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2020                     Level 1                99999       All industries
# 1  2020                     Level 1                99999       All industries
# 2  2020                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  733,258  ANZSIC06 divisions A-S (excluding classes K633...
# 1  660,630  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %%
pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv',skiprows=[1,3,5,7])
# in order to confirm this, check Variable_code column and you will see difference.
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37071  2013                     Level 3                 ZZ11
# 37072  2013                     Level 3                 ZZ11
# 37073  2013                     Level 3                 ZZ11
# 37074  2013                     Level 3                 ZZ11
# 37075  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H04
# 1                  All industries  Dollars (millions)           H07
# ...

# %% [markdown]
# ### Now replacing particular value with NaN

# %%
df11 = pd.read_csv('annual-enterprise-survey-2020-financial-year-provisional-csv.csv', na_values=['Level 1'])

# %%
df11
# Now Level 1 will be replaced by Nan values
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                         NaN                99999
# 1      2020                         NaN                99999
# 2      2020                         NaN                99999
# 3      2020                         NaN                99999
# 4      2020                         NaN                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
type(df11)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Very usefull function to get insight for numerical data BY DEFAULT present in dataframe. 
# You can also get insight for data other than numerical.
# Out:
#                Year
# count  37080.000000
# mean    2016.500000
# std        2.291319
# min     2013.000000
# 25%     2014.750000
# 50%     2016.500000
# 75%     2018.250000
# max     2020.000000

# %% [markdown]
# ### 1. count gives totsl number of rows which has records. If the value present is Nan that will be not counted.
#
#  ### count does not gurantee that you will have that much only number of rows as   shown in result.

# %% [markdown]
# ### 2. Mean is average of the total numerical observation.

# %% [markdown]
# ### 3. std refers to standard deviation of the observation. In simple words standard deviation is kind of fluctuation from mean.

# %% [markdown]
# ### 4. min and max are minimun and maximum value from the given observations

# %% [markdown]
# ### 5. Before doing below operation, data is sorted into ascending order first.
#
# ###    25% is twenty fivth percentile data which means data value available of 25th percent position of that value. Suppose you have total 12 data now 25% means data value present at 4th position.
#
#
# ###    Similarly 50% means data value what is present at half and 75% means that data value present at 3/4 of distribution.

# %%
print([0,[1,2,3,4,5][2],2][1])
# Out:
# 3

# %%
df.dtypes
# Above command returns data type for each and evry column.
# int64 is integer data type
# object is string data type
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %% [markdown]
# In order to remove default index we can mentioned --> index = False as shown below

# %%
df22=df

# %%
df22
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df22.to_csv("result.csv",index=False)
# open this via excel and you won't see default index

# %%
df22.to_csv("result1.csv",index=False,header=False)
# now you won't have first row as colunm when you open in excel.

# %% [markdown]
# ### Replacing default seperator by our own separator as whon below.

# %%
df22.to_csv("result1.csv",index=False,header=False,sep='#')

# %%
df22
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2020                     Level 1                99999
# 1      2020                     Level 1                99999
# 2      2020                     Level 1                99999
# 3      2020                     Level 1                99999
# 4      2020                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2013                     Level 3                 ZZ11
# 37076  2013                     Level 3                 ZZ11
# 37077  2013                     Level 3                 ZZ11
# 37078  2013                     Level 3                 ZZ11
# 37079  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# ### Selecting particular colunms from given dataframe.

# %%
df22.columns
# to get all coulmns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df22['Year']
# Out:
# 0        2020
# 1        2020
# 2        2020
# 3        2020
# 4        2020
#          ...
# 37075    2013
# 37076    2013
# 37077    2013
# 37078    2013
# 37079    2013
# Name: Year, Length: 37080, dtype: int64

# %%
type(df22['Year'])
# Only one column is know as SERIES.
# More than column is known as dataframe.
# Series is a subset of dataframe
# Out:
# pandas.core.series.Series

# %%
df22[['Year']]
# Out:
#        Year
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 37075  2013
# 37076  2013
# 37077  2013
# 37078  2013
# 37079  2013
#
# [37080 rows x 1 columns]

# %%
type(df22[['Year']])
# Above technique is used to convert Series into dataframe.
# Out:
# pandas.core.frame.DataFrame

# %%
df22.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df22[['Year','Value']]
# Using above technique we can extract multiple columns
# Out:
#        Year    Value
# 0      2020  733,258
# 1      2020  660,630
# 2      2020   54,342
# 3      2020   18,285
# 4      2020  654,872
# ...     ...      ...
# 37075  2013       52
# 37076  2013       40
# 37077  2013       12
# 37078  2013        5
# 37079  2013       46
#
# [37080 rows x 2 columns]

# %%
df22[['Year','Value','Industry_code_ANZSIC06']]
# Out:
#        Year    Value                             Industry_code_ANZSIC06
# 0      2020  733,258  ANZSIC06 divisions A-S (excluding classes K633...
# 1      2020  660,630  ANZSIC06 divisions A-S (excluding classes K633...
# 2      2020   54,342  ANZSIC06 divisions A-S (excluding classes K633...
# 3      2020   18,285  ANZSIC06 divisions A-S (excluding classes K633...
# 4      2020  654,872  ANZSIC06 divisions A-S (excluding classes K633...
# ...     ...      ...                                                ...
# 37075  2013       52  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37076  2013       40  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37077  2013       12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37078  2013        5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37079  2013       46  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [37080 rows x 3 columns]

# %% [markdown]
# ### Reading data from excel sheet

# %%
pd.read_excel('cars.xls')
# By default it will read out first sheet from the excel file.
# Out:
#       MPG  CYL    ENG   WGT
# 0    18.0    8  307.0  3504
# 1    15.0    8  350.0  3693
# 2    18.0    8  318.0  3436
# 3    16.0    8  304.0  3433
# 4    17.0    8  302.0  3449
# ..    ...  ...    ...   ...
# 387  27.0    4  140.0  2790
# 388  44.0    4   97.0  2130
# 389  32.0    4  135.0  2295
# 390  28.0    4  120.0  2625
# 391  31.0    4  119.0  2720
#
# [392 rows x 4 columns]

# %% [markdown]
# ### Reading data from a particular sheet in given execel file

# %%
pd.read_excel('cars.xls',sheet_name='sheet_2')
# We use parameter sheet_name to read the data from a particular execel sheet.
# Out:
#     YEAR          Q      Y      PCHICK       PBEEF        PCOR          PF  \
# 0   1950  14.300000   7863   69.500000   31.200001   59.799999         NaN
# 1   1951  15.100000   7953   72.900002   36.500000   72.099998         NaN
# 2   1952  15.300000   8071   73.099998   36.200001   71.300003         NaN
# 3   1953  15.200000   8319   71.300003   28.500000   62.700001         NaN
# 4   1954  15.800000   8276   64.400002   27.400000   63.400002         NaN
# 5   1955  14.700000   8675   67.000000   27.100000   56.099998         NaN
# 6   1956  16.799999   8930   58.799999   26.700001   57.700001         NaN
# 7   1957  17.600000   8988   57.299999   28.700001   51.599998         NaN
# 8   1958  19.299999   8922   56.599998   33.400002   50.099998         NaN
# 9   1959  19.799999   9167   51.599998   34.400002   48.599998         NaN
# 10  1960  19.200001   9210   52.400002   33.500000   46.000000   51.533611
# ...

# %% [markdown]
# ### Reading data from HTML pages.

# %%
df55 = pd.read_html('https://www.basketball-reference.com/players/j/jordami01.html')

# %% [markdown]
# ### pd.read_html('page address') tries to read html data. It will read all table and the type of data will be in form of list. If there is no table then data is not stored.

# %%
df55
# Out:
# [        Season   Age                                                 Tm  \
#  0      1984-85  21.0                                                CHI
#  1      1985-86  22.0                                                CHI
#  2      1986-87  23.0                                                CHI
#  3      1987-88  24.0                                                CHI
#  4      1988-89  25.0                                                CHI
#  5      1989-90  26.0                                                CHI
#  6      1990-91  27.0                                                CHI
#  7      1991-92  28.0                                                CHI
#  8      1992-93  29.0                                                CHI
#  9      1993-94  30.0  Did Not Play (Minor League Baseball—Birmingham...
#  10     1994-95  31.0                                                CHI
#  11     1995-96  32.0                                                CHI
# ...

# %%
type(df55)
# Out:
# list

# %% [markdown]
# ### To know how many tables does a HTML pages contains

# %%
len(df55)
# This table contains 6 tables
# Out:
# 6

# %%
df55[0]
# First table
# Out:
#         Season   Age                                                 Tm  \
# 0      1984-85  21.0                                                CHI
# 1      1985-86  22.0                                                CHI
# 8      1992-93  29.0  CHI  NBA   SG   19.0   783.0  30.1  0.553  0.136  ...
# 9      1994-95  31.0  CHI  NBA   SG   10.0   420.0  24.8  0.557  0.121  ...
# 10     1995-96  32.0  CHI  NBA   SG   18.0   733.0  26.7  0.564  0.152  ...
# ...

# %% [markdown]
# ### Dumping above table in form of csv

# %%
df55[5].to_csv('Dump.csv')

# %%
pd.read_csv('Dump.csv')
# Out:
#     Unnamed: 0      Season   Age   Tm   Lg  Pos      G      MP   PER    TS%  \
# 0            0     1984-85  21.0  CHI  NBA   SG    4.0   171.0  24.7  0.565
# 1            1     1985-86  22.0  CHI  NBA   SG    3.0   135.0  30.1  0.584
# 2            2     1986-87  23.0  CHI  NBA   SG    3.0   128.0  28.1  0.529
# 3            3     1987-88  24.0  CHI  NBA   SG   10.0   427.0  28.4  0.598
# 4            4     1988-89  25.0  CHI  NBA   SG   17.0   718.0  29.9  0.602
# 5            5     1989-90  26.0  CHI  NBA   SG   16.0   674.0  31.7  0.592
# 6            6     1990-91  27.0  CHI  NBA   SG   17.0   689.0  32.0  0.600
# 7            7     1991-92  28.0  CHI  NBA   SG   22.0   920.0  27.2  0.571
# 8            8     1992-93  29.0  CHI  NBA   SG   19.0   783.0  30.1  0.553
# 9            9     1994-95  31.0  CHI  NBA   SG   10.0   420.0  24.8  0.557
# 10          10     1995-96  32.0  CHI  NBA   SG   18.0   733.0  26.7  0.564
# ...

# %% [markdown]
# ### Reading a csv file present on github

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Creating a dataframe

# %%
df = pd.DataFrame(

    {
        "Name" : ["Anmol","Abhi","Reyu","Adhu"],
        "Age" : [26,21,6,15],
        "Favorite Dish" : ["Butter Chicken","Mutton","Fish","Duck"]
    }
)

# %%
df
# Out:
#     Name  Age   Favorite Dish
# 0  Anmol   26  Butter Chicken
# 1   Abhi   21          Mutton
# 2   Reyu    6            Fish
# 3   Adhu   15            Duck

# %%
{
 "$schema": "https://schema.management.azure.com/schemas/2015-01-01/deploymentParameters.json Jump #",
 "contentVersion": "1.0.0.0",
 "parameters": {
 "location": {
 "value": "eastus"---Look at location this is EastUS what we selected
 },
 "networkInterfaceName": {
 "value": "azuretestvm974"
 },
 "networkSecurityGroupName": {
 "value": "AzureTestVM-nsg"--This is the NSG name
 },
 "networkSecurityGroupRules": {
 "value": [
 {
 "name": "RDP",--This is about the port which we allowed
 "properties": {
 "priority": 300,
 "protocol": "TCP",
 "access": "Allow",
 "direction": "Inbound",
 "sourceAddressPrefix": "*",
 "sourcePortRange": "*",
 "destinationAddressPrefix": "*",
 "destinationPortRange": "3389"
 }
 }
 ]
 },
 "subnetName": {
 "value": "default"
 },
 "virtualNetworkId": {
 "value": "/subscriptions/6400b22f-788d-48da-a164-b915c9678bd1/resourceGroups/test/providers/Microsoft.Network/virtualNetworks/Test-vnet"
 },
 "publicIpAddressName": {
 "value": "AzureTestVM-ip"---This is name of public IP address
 },
 "publicIpAddressType": {
 "value": "Static"
 },
 "publicIpAddressSku": {
 "value": "Standard"
 },
 "virtualMachineName": {
 "value": "AzureTestVM"---This is the VM name
 },
 "virtualMachineRG": {
 "value": "Test"
 },
 "osDiskType": {
 "value": "Standard_LRS"
 },
 "virtualMachineSize": {
 "value": "Standard_DS1_v2"
 },
 "adminUsername": {
 "value": "Shashank"
 },
 "adminPassword": {
 "value": null
 },
 "diagnosticsStorageAccountName": {
 "value": "storageacc621"   ---This is storage account name
 },
 "diagnosticsStorageAccountId": {
 "value": "/subscriptions/6400b22f-788d-48da-a164-b915c9678bd1/resourceGroups/Test/providers/Microsoft.Storage/storageAccounts/storageacc621"
 },
 "zone": {
 "value": "3"
 }
 }
}

# %%
pd.DataFrame({
 "$schema": "https://schema.management.azure.com/schemas/2015-01-01/deploymentParameters.json Jump #",
 "contentVersion": "1.0.0.0",
 "parameters": {
 "location": {
 "value": "eastus"
 },
 "networkInterfaceName": {
 "value": "azuretestvm974"
 },
 "networkSecurityGroupName": {
 "value": "AzureTestVM-nsg"
 },
 "networkSecurityGroupRules": {
 "value": [
 {
 "name": "RDP",
 "properties": {
 "priority": 300,
 "protocol": "TCP",
 "access": "Allow",
 "direction": "Inbound",
 "sourceAddressPrefix": "*",
 "sourcePortRange": "*",
 "destinationAddressPrefix": "*",
 "destinationPortRange": "3389"
 }
 }
 ]
 },
 "subnetName": {
 "value": "default"
 },
 "virtualNetworkId": {
 "value": "/subscriptions/6400b22f-788d-48da-a164-b915c9678bd1/resourceGroups/test/providers/Microsoft.Network/virtualNetworks/Test-vnet"
 },
 "publicIpAddressName": {
 "value": "AzureTestVM-ip"
 },
 "publicIpAddressType": {
 "value": "Static"
 },
 "publicIpAddressSku": {
 "value": "Standard"
 },
 "virtualMachineName": {
 "value": "AzureTestVM"
 },
 "virtualMachineRG": {
 "value": "Test"
 },
 "osDiskType": {
 "value": "Standard_LRS"
 },
 "virtualMachineSize": {
 "value": "Standard_DS1_v2"
 },
 "adminUsername": {
 "value": "Shashank"
 },
 "adminPassword": {
 "value": "Passowrd"
 },
 "diagnosticsStorageAccountName": {
 "value": "storageacc621" 
 },
 "diagnosticsStorageAccountId": {
 "value": "/subscriptions/6400b22f-788d-48da-a164-b915c9678bd1/resourceGroups/Test/providers/Microsoft.Storage/storageAccounts/storageacc621"
 },
 "zone": {
 "value": "3"
 }
 }
})
# Out:
#                                                                          $schema  \
# adminPassword                  https://schema.management.azure.com/schemas/20...
# adminUsername                  https://schema.management.azure.com/schemas/20...
# diagnosticsStorageAccountId    https://schema.management.azure.com/schemas/20...
# diagnosticsStorageAccountName  https://schema.management.azure.com/schemas/20...
# location                       https://schema.management.azure.com/schemas/20...
# networkInterfaceName           https://schema.management.azure.com/schemas/20...
# networkSecurityGroupName       https://schema.management.azure.com/schemas/20...
# networkSecurityGroupRules      https://schema.management.azure.com/schemas/20...
# osDiskType                     https://schema.management.azure.com/schemas/20...
# publicIpAddressName            https://schema.management.azure.com/schemas/20...
# publicIpAddressSku             https://schema.management.azure.com/schemas/20...
# ...
