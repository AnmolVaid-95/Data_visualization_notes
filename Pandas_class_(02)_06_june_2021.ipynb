# %%
import pandas as pd

# %% [markdown]
# #### The pickle module implements binary protocols for serializing and de-serializing a Python object structure. “Pickling” is the process whereby a Python object hierarchy is converted into a byte stream, and “unpickling” is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy. Pickling (and unpickling) is alternatively known as “serialization”, “marshalling,” or “flattening”; however, to avoid confusion, the terms used here are “pickling” and “unpickling”.

# %%
pd.read_csv('Dump.csv')
# Out:
#     Unnamed: 0      Season   Age   Tm   Lg  Pos      G      MP   PER    TS%  \
# 0            0     1984-85  21.0  CHI  NBA   SG    4.0   171.0  24.7  0.565
# 1            1     1985-86  22.0  CHI  NBA   SG    3.0   135.0  30.1  0.584
# 2            2     1986-87  23.0  CHI  NBA   SG    3.0   128.0  28.1  0.529
# 3            3     1987-88  24.0  CHI  NBA   SG   10.0   427.0  28.4  0.598
# 4            4     1988-89  25.0  CHI  NBA   SG   17.0   718.0  29.9  0.602
# 5            5     1989-90  26.0  CHI  NBA   SG   16.0   674.0  31.7  0.592
# 6            6     1990-91  27.0  CHI  NBA   SG   17.0   689.0  32.0  0.600
# 7            7     1991-92  28.0  CHI  NBA   SG   22.0   920.0  27.2  0.571
# 8            8     1992-93  29.0  CHI  NBA   SG   19.0   783.0  30.1  0.553
# 9            9     1994-95  31.0  CHI  NBA   SG   10.0   420.0  24.8  0.557
# 10          10     1995-96  32.0  CHI  NBA   SG   18.0   733.0  26.7  0.564
# ...

# %%
from_file = pd.read_csv('Dump.csv')

# %%
from_file.to_pickle("my_pickle")

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BAA2-FA19
#
#  Directory of C:\Users\ANMOL\Desktop\ineuron_assign\Data_visualization_notes
#
# 25-09-2021  05:15 PM    <DIR>          .
# 25-09-2021  05:15 PM    <DIR>          ..
# 25-09-2021  05:07 PM    <DIR>          .ipynb_checkpoints
# 25-09-2021  03:22 PM            22,016 broiler.xls
# 25-09-2021  03:28 PM            55,808 cars.xls
# 25-09-2021  03:55 PM             2,175 Dump.csv
# 25-09-2021  05:15 PM             5,155 my_pickle
# 24-09-2021  10:48 PM           871,956 Pandas session 1.ipynb
# 25-09-2021  04:31 PM           510,385 Pandas_class_(01)_05_june_2021.ipynb
# 25-09-2021  05:13 PM            24,768 Pandas_class_(02)_06_june_2021.ipynb
#                7 File(s)      1,492,263 bytes
#                3 Dir(s)  126,325,198,848 bytes free

# %%
from_file
# Out:
#     Unnamed: 0      Season   Age   Tm   Lg  Pos      G      MP   PER    TS%  \
# 0            0     1984-85  21.0  CHI  NBA   SG    4.0   171.0  24.7  0.565
# 1            1     1985-86  22.0  CHI  NBA   SG    3.0   135.0  30.1  0.584
# 2            2     1986-87  23.0  CHI  NBA   SG    3.0   128.0  28.1  0.529
# 3            3     1987-88  24.0  CHI  NBA   SG   10.0   427.0  28.4  0.598
# 4            4     1988-89  25.0  CHI  NBA   SG   17.0   718.0  29.9  0.602
# 5            5     1989-90  26.0  CHI  NBA   SG   16.0   674.0  31.7  0.592
# 6            6     1990-91  27.0  CHI  NBA   SG   17.0   689.0  32.0  0.600
# 7            7     1991-92  28.0  CHI  NBA   SG   22.0   920.0  27.2  0.571
# 8            8     1992-93  29.0  CHI  NBA   SG   19.0   783.0  30.1  0.553
# 9            9     1994-95  31.0  CHI  NBA   SG   10.0   420.0  24.8  0.557
# 10          10     1995-96  32.0  CHI  NBA   SG   18.0   733.0  26.7  0.564
# ...

# %%
pd.read_pickle('my_pickle')
# Out:
#     Unnamed: 0      Season   Age   Tm   Lg  Pos      G      MP   PER    TS%  \
# 0            0     1984-85  21.0  CHI  NBA   SG    4.0   171.0  24.7  0.565
# 1            1     1985-86  22.0  CHI  NBA   SG    3.0   135.0  30.1  0.584
# 2            2     1986-87  23.0  CHI  NBA   SG    3.0   128.0  28.1  0.529
# 3            3     1987-88  24.0  CHI  NBA   SG   10.0   427.0  28.4  0.598
# 4            4     1988-89  25.0  CHI  NBA   SG   17.0   718.0  29.9  0.602
# 5            5     1989-90  26.0  CHI  NBA   SG   16.0   674.0  31.7  0.592
# 6            6     1990-91  27.0  CHI  NBA   SG   17.0   689.0  32.0  0.600
# 7            7     1991-92  28.0  CHI  NBA   SG   22.0   920.0  27.2  0.571
# 8            8     1992-93  29.0  CHI  NBA   SG   19.0   783.0  30.1  0.553
# 9            9     1994-95  31.0  CHI  NBA   SG   10.0   420.0  24.8  0.557
# 10          10     1995-96  32.0  CHI  NBA   SG   18.0   733.0  26.7  0.564
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is BAA2-FA19
#
#  Directory of C:\Users\ANMOL\Desktop\ineuron_assign\Data_visualization_notes
#
# 25-09-2021  05:23 PM    <DIR>          .
# 25-09-2021  05:23 PM    <DIR>          ..
# 25-09-2021  05:07 PM    <DIR>          .ipynb_checkpoints
# 25-09-2021  03:22 PM            22,016 broiler.xls
# 25-09-2021  03:28 PM            55,808 cars.xls
# 25-09-2021  03:55 PM             2,175 Dump.csv
# 25-09-2021  05:15 PM             5,155 my_pickle
# 24-09-2021  10:48 PM           871,956 Pandas session 1.ipynb
# 25-09-2021  04:31 PM           510,385 Pandas_class_(01)_05_june_2021.ipynb
# 25-09-2021  05:23 PM            59,746 Pandas_class_(02)_06_june_2021.ipynb
#                7 File(s)      1,527,241 bytes
#                3 Dir(s)  126,321,897,472 bytes free

# %% [markdown]
# #### Writing a data is called Serialization.
#
# #### Reading a data means Deserialization.
#
# #### Both combined becomes SerDe

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Below command gives data type on each and every colunm
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### Checking a specific datatype

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Above command give us colunm name of those having value as object.
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Extracted all data which has column entry as object.
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1 = df[df.dtypes[df.dtypes == 'object'].index]

# %%
df1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df1.describe()
# Out:
#                        Name   Sex  Ticket        Cabin Embarked
# count                   891   891     891          204      889
# unique                  891     2     681          147        3
# top     Herman, Miss. Alice  male  347082  C23 C25 C27        S
# freq                      1   577       7            4      644

# %%
df1[df1.Name == "Herman, Miss. Alice"]
# To extract a record with a prticular value.
# In this case we extract record based on name.
# Out:
#                     Name     Sex  Ticket Cabin Embarked
# 615  Herman, Miss. Alice  female  220845   NaN        S

# %%
df1[df1.Sex=="male"]
# Extracting data based on Sex category
# Out:
#                                Name   Sex            Ticket Cabin Embarked
# 0           Braund, Mr. Owen Harris  male         A/5 21171   NaN        S
# 4          Allen, Mr. William Henry  male            373450   NaN        S
# 5                  Moran, Mr. James  male            330877   NaN        Q
# 6           McCarthy, Mr. Timothy J  male             17463   E46        S
# 7    Palsson, Master. Gosta Leonard  male            349909   NaN        S
# ..                              ...   ...               ...   ...      ...
# 883   Banfield, Mr. Frederick James  male  C.A./SOTON 34068   NaN        S
# 884          Sutehall, Mr. Henry Jr  male   SOTON/OQ 392076   NaN        S
# 886           Montvila, Rev. Juozas  male            211536   NaN        S
# 889           Behr, Mr. Karl Howell  male            111369  C148        C
# 890             Dooley, Mr. Patrick  male            370376   NaN        Q
#
# [577 rows x 5 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=="float64"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df[['Age','Fare']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes=='float64']
# Another method of exxtracting a particular data type.
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %% [markdown]
# #### Extracting data a value from a column

# %%
df['Name'][0]
# first entry of name is extraxcted.
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df['Name'][5:10]
# Series behave like list
# All slicing and various operation applied on list
# Are applicable on Series
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Ticket'][15:50]
# Out:
# 15             248706
# 16             382652
# 17             244373
# 18             345763
# 19               2649
# 20             239865
# 21             248698
# 22             330923
# 23             113788
# 24             349909
# 25             347077
# 26               2631
# 27              19950
# 28             330959
# 29             349216
# 30           PC 17601
# 31           PC 17569
# 32             335677
# 33         C.A. 24579
# 34           PC 17604
# 35             113789
# 36               2677
# 37         A./5. 2152
# 38             345764
# 39               2651
# 40               7546
# 41              11668
# 42             349253
# 43      SC/Paris 2123
# 44             330958
# 45    S.C./A.4. 23567
# 46             370371
# 47              14311
# 48               2662
# 49             349237
# Name: Ticket, dtype: object

# %%
df[['Ticket']][15:50]
# Slicing operation can be applied on Data Frame
# Out:
#              Ticket
# 15           248706
# 16           382652
# 17           244373
# 18           345763
# 19             2649
# 20           239865
# 21           248698
# 22           330923
# 23           113788
# 24           349909
# 25           347077
# 26             2631
# 27            19950
# 28           330959
# 29           349216
# 30         PC 17601
# 31         PC 17569
# 32           335677
# 33       C.A. 24579
# 34         PC 17604
# 35           113789
# 36             2677
# 37       A./5. 2152
# 38           345764
# 39             2651
# 40             7546
# 41            11668
# 42           349253
# 43    SC/Paris 2123
# 44           330958
# 45  S.C./A.4. 23567
# 46           370371
# 47            14311
# 48             2662
# 49           349237

# %%
for i in df.columns:
    print(df[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# ...

# %% [markdown]
# #### Adding new column in Data Frame

# %%
df["Anmol"] = "Vaid"
# A Column name Anmol will be added and it will contain Vaid as all enteries.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Anmol"] = df["PassengerId"]
# Now column Anmol will contain series entries of colunm name PassengerId

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Cabin'])
# It gives how many unique values we have
# 147 is given as shown below
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique()
# To extract all unique categories from the column.
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# #### To check if a column contains a value that is null or not, use ===>df['Column_name'].isnull()

# %%
df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df['Cabin'].isna()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %% [markdown]
# #### Extracting data row wise.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ser=df['Cabin'][df['Cabin'].isnull()==False]
# fetching all data column wise where Cabin is not null

# %%
ser.index
# stored above value in ser variable.
# This contains all values that has where Cabin is not null
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
df.iloc[ser.index]
# We have extracted all rows where cabin is not null
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0:5] == df.head()
# Out:
#    PassengerId  Survived  Pclass  Name   Sex   Age  SibSp  Parch  Ticket  \
# 0         True      True    True  True  True  True   True   True    True
# 1         True      True    True  True  True  True   True   True    True
# 2         True      True    True  True  True  True   True   True    True
# 3         True      True    True  True  True  True   True   True    True
# 4         True      True    True  True  True  True   True   True    True
#
#    Fare  Cabin  Embarked  Anmol
# 0  True  False      True   True
# 1  True   True      True   True
# 2  True  False      True   True
# 3  True   True      True   True
# 4  True  False      True   True

# %%
df.iloc[[0,2]]
# Out:
#    PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 0            1         0       3  Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3   Heikkinen, Miss. Laina  female  26.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked  Anmol
# 0      1      0         A/5 21171  7.250   NaN        S      1
# 2      0      0  STON/O2. 3101282  7.925   NaN        S      3

# %%
df.iloc[[0, 2], [0, 1]]
# To access data of particular column we use another list
# In above example we have mention 0 and 1 column that we need to access for 0 and 2 row.
# Out:
#    PassengerId  Survived
# 0            1         0
# 2            3         1

# %% [markdown]
# #### Fetch all row records where survived = Null

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# #### Fetch all records wherer fare is greater than 20.00

# %%
df[df['Fare']> 20.00]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Fare']> 20.00])
# total number of records where fare is greater than 20.00
# Out:
# 376

# %% [markdown]
# #### First reach the data then try to apply filter as per given condition

# %% [markdown]
# #### Extract person name who has payed highest Fare.

# %%
df['Fare'].max()
# First we found the value of maximum fare.
# Out:
# 512.3292

# %%
df[df['Fare']==512.3292]
# Then we extracted the records who have payed maximum fare.
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      Anmol
# 258    259
# 679    680
# 737    738

# %%
df[df['Fare']==512.3292].Name
# Extracting name of person who have payed highest fare.
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [markdown]
# #### Combining two columns and making a new column having these two columns combined result.

# %%
df['new_column'] = df['PassengerId'] + df['Age']

# %%
df
# Nan + known value = Nan
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Cabin'].isna()]
# extracting those values where vale of Cabin is NaN.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
a=df[df['Cabin'].isna()].Cabin

# %%
for i in a :
    print(i)
# Verifying that all values consist of nan only using for loop
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
df[df['Cabin'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep= '\t')

# %%
df5
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# #### Removing "$" from item price from given dataframe.

# %%
df5['item_price'].replace("$",'')
# Out:
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df5['item_price']=df5['item_price'].str.replace('$','',regex=True)
df5
# Removed $ sign from item price.
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
df5
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
df6 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
df6
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df7 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt',sep=' ')

# %%
df7
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %% [markdown]
# #### Removing '_' from the name

# %%
df7['name'] = df7['name'].str.replace('_',' ')

# %%
df7
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs Bohemian Style       149      27      4.7  0.42
# 8            Miller Lite        99      10      4.3  0.43
# 9        Budweiser Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors Light       102      15      4.1  0.46
# 12        Michelob Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df22 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
df22
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
df44= pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df44
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1735     vcd       UKSoccer
# 1736     vcd   VisualAcuity
# 1737     vcd        VonBort
# 1738     vcd     WeldonDice
# 1739     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df44['CSV'] = df44['CSV'].str.replace('https://','')
# Removing https:// from CSV column

# %%
df44
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1735     vcd       UKSoccer
# 1736     vcd   VisualAcuity
# 1737     vcd        VonBort
# 1738     vcd     WeldonDice
# 1739     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df55 = pd.read_csv('https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view')

# %%
df55
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="Qte5O9MEp7oNyZ9yb79jqg">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>pandas practice.pdf - Google Drive</title><meta property="og:title" content="pandas practice.pdf"><meta property="og:type" content="article"><meta property="og:
# ...
